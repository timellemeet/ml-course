# %% [markdown]
# Import packages and load image

# %%
from PIL import Image
import numpy as np
from sklearn.cluster import KMeans

image = np.array(Image.open("sample.jpg"))
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FECDA99DE48>

# %% [markdown]
# ***K***-means algorithm

# %%
# Reshape it to be 2-dimension
k_image = image.reshape(image.shape[0] * image.shape[1], image.shape[2])
kmeans = KMeans(n_clusters=2, random_state=0).fit(k_image)

# %% [markdown]
# Agglomerative hierarchical clustering algorithm

# %% [markdown]
# Spectral clustering algorithm
